# %%
Courses = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/FileStore/Courses-2.csv")
Courses.createOrReplaceTempView("Courses")
Department = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/FileStore/Department-3.csv")
Department.createOrReplaceTempView("Department")
Schedule = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/FileStore/Schedule-1.csv")
Schedule.createOrReplaceTempView("Schedule")
Professor = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/FileStore/Professor-1.csv")
Professor.createOrReplaceTempView("Professor")

# %%
Courses.show()
Department.show()
Schedule.show()
Professor.show()
# Out:
# +----+-------------------+-------------+-------+
# |  ID|               NAME|DEPARTMENT_ID|CREDITS|
# +----+-------------------+-------------+-------+
# |ads1|algo_data_structure|          cs1|      2|
# | ca1|     Computer archi|          cs1|      4|
# | qp1|    quantum_physics|          ph1|      4|
# | dm1|    data_management|          se1|      7|
# +----+-------------------+-------------+-------+
#
# +---+------------+
# | ID|        NAME|
# +---+------------+
# |se1|   software |
# |cs1|comp_science|
# |ph1|     Physics|
# +---+------------+
#
# +------------+---------+--------+----+
# |PROFESSOR_ID|COURSE_ID|SEMESTER|YEAR|
# +------------+---------+--------+----+
# |          P1|      dm1|       2|2021|
# |          P1|     ads1|       7|2022|
# |          P2|      ca1|       8|2020|
# |          P2|      dm1|       3|2022|
# |          P3|      qp1|       1|2021|
# +------------+---------+--------+----+
#
# +---+------+-------------+------+
# | ID|  NAME|DEPARTMENT_ID|SALARY|
# +---+------+-------------+------+
# | P1|sahana|          se1| 10000|
# | P2| Soham|          cs1| 12000|
# | P3| Rahul|          ph1|  8000|
# | P4| Bunty|          ph2|   800|
# | P5|Shenaz|          se1| 10000|
# | P6|Nikhil|          cs1|  9000|
# +---+------+-------------+------+

# %%
Schedule.show()
# Out:
# +------------+---------+--------+----+
# |PROFESSOR_ID|COURSE_ID|SEMESTER|YEAR|
# +------------+---------+--------+----+
# |          P1|      dm1|       2|2021|
# |          P1|     ads1|       7|2022|
# |          P2|      ca1|       8|2020|
# |          P2|      dm1|       3|2022|
# |          P3|      qp1|       1|2021|
# +------------+---------+--------+----+

# %%
Courses.show()
# Out:
# +----+-------------------+-------------+-------+
# |  ID|               NAME|DEPARTMENT_ID|CREDITS|
# +----+-------------------+-------------+-------+
# |ads1|algo_data_structure|          cs1|      2|
# | ca1|     Computer archi|          cs1|      4|
# | qp1|    quantum_physics|          ph1|      4|
# | dm1|    data_management|          se1|      7|
# +----+-------------------+-------------+-------+

# %%
Department.show()
# Out:
# +---+------------+
# | ID|        NAME|
# +---+------------+
# |se1|   software |
# |cs1|comp_science|
# |ph1|     Physics|
# +---+------------+

# %%
# %sql

Select Schedule.PROFESSOR_ID, Courses.ID as Course_id, Courses.NAME as COURSE_NAME, Professor.NAME AS Professor_name, Professor.DEPARTMENT_ID as p_dept_id, Courses.DEPARTMENT_ID as c_dept_id from Schedule 
join Courses on Schedule.COURSE_ID = Courses.ID
join Professor on Professor.ID = Schedule.PROFESSOR_ID
where Professor.DEPARTMENT_ID <> Courses.DEPARTMENT_ID
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PROFESSOR_ID</th><th>Course_id</th><th>COURSE_NAME</th><th>Professor_name</th><th>p_dept_id</th><th>c_dept_id</th></tr></thead><tbody><tr><td>P1</td><td>ads1</td><td>algo_data_structure</td><td>sahana</td><td>se1</td><td>cs1</td></tr><tr><td>P2</td><td>dm1</td><td>data_management</td><td>Soham</td><td>cs1</td><td>se1</td></tr></tbody></table></div>

# %%
Professor.show()
# Out:
# +---+------+-------------+------+
# | ID|  NAME|DEPARTMENT_ID|SALARY|
# +---+------+-------------+------+
# | P1|sahana|          se1| 10000|
# | P2| Soham|          cs1| 12000|
# | P3| Rahul|          ph1|  8000|
# | P4| Bunty|          ph2|   800|
# | P5|Shenaz|          se1| 10000|
# | P6|Nikhil|          cs1|  9000|
# +---+------+-------------+------+

# %%
Department.show()
# Out:
# +---+------------+
# | ID|        NAME|
# +---+------------+
# |se1|   software |
# |cs1|comp_science|
# |ph1|     Physics|
# +---+------------+

# %%
# %sql

select d.Name, p.Salary,p.Name as Prof_name, d_rank from Department d join 
(select *,dense_rank() over(order by salary) as d_rank from Professor) p
on d.ID = p.DEPARTMENT_ID
where d_rank in (1,2,3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Salary</th><th>Prof_name</th><th>d_rank</th></tr></thead><tbody><tr><td>software </td><td>10000</td><td>sahana</td><td>1</td></tr><tr><td>software </td><td>10000</td><td>Shenaz</td><td>1</td></tr><tr><td>comp_science</td><td>12000</td><td>Soham</td><td>2</td></tr></tbody></table></div>
